# %% [markdown]
# **Data Visualization**
#
#
# **Exploratory Data Analysis (EDA)**
#
# 1) Univariate Analysis - Where we are taking only one variable and analysing that
# Eg: Age of customers (Numerical variable), Customers based on Gender (Categorical variable)
#
# 2) Bivariate Analysis - Numerical - Numerical, Categorical - Numerical, Categorical - Categorical (We may prefer to create the crosstab datatable)
#
# 3) Multivariate Analysis - When we have 3 or more than 3 variables

# %% [markdown]
# **Matplotlib**
# **https://matplotlib.org/stable/index.html**
#
# **Seaborn**
# **https://seaborn.pydata.org/**

# %%
import os
os.chdir(r'E:\SmartCube\End to End Code')

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Python_Credit_Risk_XTrain.csv')

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# **Matplotlib**

# %%
for group,data in df.groupby('Property_Area'):
    print(group,data['ApplicantIncome'].mean())
# Out:
# Rural 5554.083798882682
# Semiurban 5292.261802575107
# Urban 5398.247524752475

# %%
plt.figure(figsize=(7,2))
for group,data in df.groupby('Property_Area'):
    plt.barh(group,data['ApplicantIncome'].mean())
plt.xlabel('Avg Applicant Income')
plt.ylabel('Property Area')
plt.title('Property Area vs Avg. Applicant Income')
plt.show()

# %%
df.groupby(['Property_Area','Gender']).size()
# Out:
# Property_Area  Gender
# Rural          Female     24
#                Male      151
# Semiurban      Female     55
#                Male      172
# Urban          Female     33
#                Male      166
# dtype: int64

# %%
plt.hist(df['ApplicantIncome'])
plt.xlabel('Applicant Income')
plt.ylabel('Frequency')
plt.show()

# %%
plt.scatter(df['ApplicantIncome'], df['LoanAmount'])
#plt.xlim((0,20000))
#plt.ylim((0,500))

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.countplot(data=df, x='Gender',hue='Loan_Status')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df, x='Married',hue='Loan_Status')
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
df.groupby(['Married','Gender','Loan_Status']).size()
# Out:
# Married  Gender  Loan_Status
# No       Female  0               29
#                  1               51
#          Male    0               49
#                  1               81
# Yes      Female  0                8
#                  1               23
#          Male    0              101
#                  1              256
# dtype: int64

# %%
sns.countplot(data=df, x='Property_Area',hue='Loan_Status')
# Out:
# <Axes: xlabel='Property_Area', ylabel='count'>

# %%
df.groupby(['Gender','Dependents','Credit_History','Education','Loan_Status']).size().sort_values(ascending=False)
# Out:
# Gender  Dependents  Credit_History  Education     Loan_Status
# Male    0           1.0             Graduate      1              135
#         2           1.0             Graduate      1               52
#         1           1.0             Graduate      1               36
# Female  0           1.0             Graduate      1               35
# Male    0           1.0             Graduate      0               33
#                                     Not Graduate  1               28
#         3+          1.0             Graduate      1               19
#         0           0.0             Graduate      0               15
#         2           1.0             Not Graduate  1               13
#         0           0.0             Not Graduate  0               13
#                     1.0             Not Graduate  0               12
# Female  0           1.0             Graduate      0               12
# Male    1           1.0             Graduate      0               11
# ...

# %%
df.groupby(['Gender','Dependents','Credit_History','Education','Loan_Status','Property_Area']).size().sort_values(ascending=False)
# Out:
# Gender  Dependents  Credit_History  Education     Loan_Status  Property_Area
# Male    0           1.0             Graduate      1            Semiurban        59
#                                                                Urban            40
#                                                                Rural            36
# Female  0           1.0             Graduate      1            Semiurban        20
# Male    2           1.0             Graduate      1            Semiurban        19
#                                                                                 ..
#         1           1.0             Not Graduate  0            Urban             1
#         2           0.0             Graduate      1            Semiurban         1
#                                     Not Graduate  0            Rural             1
#                                                                Urban             1
# ...

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.lmplot(data=df,x='ApplicantIncome',y='CoapplicantIncome',fit_reg=False,hue='Loan_Status')

# %%
sns.lmplot(data=df,x='ApplicantIncome',y='LoanAmount',fit_reg=False,hue='Loan_Status')

# %%
os.chdir(r'E:\Courses\Python Basics to Advanced')

# %%
df_car  = pd.read_csv('Car_sales.csv')

# %%
df_car
# Out:
#       Manufacturer              Model  Sales in thousands  \
# 0       Mitsubishi  3000GT                          0.110
# 1            Dodge  Viper                           0.916
# 2    Mercedes-Benz  CL500                           0.954
# 3       Oldsmobile  Cutlass                         1.112
# 4          Porsche  Carrera Coupe                   1.280
# ..             ...                ...                 ...
# 152          Honda  Accord                        230.902
# 153           Ford  Taurus                        245.815
# 154         Toyota  Camry                         247.994
# 155           Ford  Explorer                      276.747
# 156           Ford  F-Series                      540.561
#
#      4-year resale value Vehicle type  Price in thousands  Engine size  \
# 0              20.940000    Passenger              25.450          3.0
# 1              58.470000    Passenger              69.725          8.0
# ...

# %%
sns.distplot(df_car['Fuel efficiency'],kde=False)
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_31072\2009607686.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_car['Fuel efficiency'],kde=False)
# <Axes: xlabel='Fuel efficiency'>

# %%
df_car[df_car['Fuel efficiency']>40]
# Out:
#    Manufacturer              Model  Sales in thousands  4-year resale value  \
# 61    Chevrolet  Metro                          21.855                 5.16
#
#    Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 61    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# 61   62.6   149.4        1.895           10.3             45.0     13-Apr-14

# %%
sns.lmplot(data=df_car, x='Fuel capacity',y='Fuel efficiency',fit_reg=False,hue='Vehicle type')

# %%
sns.jointplot(data=df_car, x='Fuel capacity',y='Fuel efficiency')

# %%
sns.lmplot(data=df_car,x='Fuel capacity',y='Fuel efficiency', hue='Vehicle type', col='Vehicle type')

# %%
sns.countplot(data=df_car,x='Vehicle type')
# Out:
# <Axes: xlabel='Vehicle type', ylabel='count'>

# %%
sns.barplot(data=df_car, y='Vehicle type', x='4-year resale value')
# Out:
# <Axes: xlabel='4-year resale value', ylabel='Vehicle type'>

# %%
sns.stripplot(data=df_car, y='Vehicle type', x='4-year resale value')
# Out:
# <Axes: xlabel='4-year resale value', ylabel='Vehicle type'>

# %%
sns.pairplot(df_car[['Horsepower','Curb weight','Fuel capacity','Fuel efficiency','Vehicle type']],hue='Vehicle type')

# %%
sns.heatmap(df_car[['Horsepower','Curb weight','Fuel capacity','Fuel efficiency','Vehicle type']].corr(),annot=True)
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_31072\1525637864.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_car[['Horsepower','Curb weight','Fuel capacity','Fuel efficiency','Vehicle type']].corr(),annot=True)
# <Axes: >

# %%
sns.heatmap(df_car[['Horsepower','Curb weight','Fuel capacity','Fuel efficiency','Vehicle type']].corr(),annot=True)
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_31072\1525637864.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_car[['Horsepower','Curb weight','Fuel capacity','Fuel efficiency','Vehicle type']].corr(),annot=True)
# <Axes: >

# %%
sns.boxplot(data=df_car, y='Vehicle type', x='Fuel efficiency')
# Out:
# <Axes: xlabel='Fuel efficiency', ylabel='Vehicle type'>

# %%
df_car.describe()
# Out:
#        Sales in thousands  4-year resale value  Price in thousands  \
# count          157.000000           157.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            10.045282           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            12.545000           18.017500
# 50%             29.450000            17.710000           22.799000
# 75%             67.956000            18.140000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  157.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.518297    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
sns.distplot(df_car['Sales in thousands'])
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_31072\3390915631.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_car['Sales in thousands'])
# <Axes: xlabel='Sales in thousands', ylabel='Density'>

# %%
sns.boxplot(data=df_car, x='Sales in thousands')
# Out:
# <Axes: xlabel='Sales in thousands'>

# %%
sns.violinplot(data=df_car, x='Sales in thousands')
# Out:
# <Axes: xlabel='Sales in thousands'>
