# %%
import os

# %%
import pandas as pd

# %%
os.chdir(r'C:\Users\rahul\Downloads\Data-20230916T024120Z-001\Data')

# %%
df_1 = pd.read_csv('AdventureWorks_Returns.csv')

# %%
df_2 = pd.read_csv('AdventureWorks_Products.csv')

# %%
df_3 = pd.read_csv('AdventureWorks_Product_Subcategories.csv')

# %%
df_4 = pd.read_csv('AdventureWorks_Product_Categories.csv')

# %%
df_5= pd.read_csv('AdventureWorks_Territories.csv')

# %%
df_1
# Out:
#      ReturnDate  TerritoryKey  ProductKey  ReturnQuantity
# 0     1/18/2015             9         312               1
# 1     1/18/2015            10         310               1
# 2     1/21/2015             8         346               1
# 3     1/22/2015             4         311               1
# 4      2/2/2015             6         312               1
# ...         ...           ...         ...             ...
# 1804  6/30/2017             6         491               1
# 1805  6/30/2017             8         477               1
# 1806  6/30/2017             9         477               1
# 1807  6/30/2017            10         223               1
# 1808  6/30/2017            10         477               1
#
# [1809 rows x 4 columns]

# %%
df_2
# Out:
#      ProductKey  ProductSubcategoryKey  ProductSKU              ProductName  \
# 0           214                     31   HL-U509-R    Sport-100 Helmet, Red
# 1           215                     31     HL-U509  Sport-100 Helmet, Black
# 2           218                     23   SO-B909-M   Mountain Bike Socks, M
# 3           219                     23   SO-B909-L   Mountain Bike Socks, L
# 4           220                     31   HL-U509-B   Sport-100 Helmet, Blue
# ..          ...                    ...         ...                      ...
# 288         602                      5     BB-8107        ML Bottom Bracket
# 289         603                      5     BB-9108        HL Bottom Bracket
# 290         604                      2  BK-R19B-44       Road-750 Black, 44
# 291         605                      2  BK-R19B-48       Road-750 Black, 48
# 292         606                      2  BK-R19B-52       Road-750 Black, 52
#
# ...

# %%
df_3
# Out:
#     ProductSubcategoryKey    SubcategoryName  ProductCategoryKey
# 0                       1     Mountain Bikes                   1
# 1                       2         Road Bikes                   1
# 2                       3      Touring Bikes                   1
# 3                       4         Handlebars                   2
# 4                       5    Bottom Brackets                   2
# 5                       6             Brakes                   2
# 6                       7             Chains                   2
# 7                       8          Cranksets                   2
# 8                       9        Derailleurs                   2
# 9                      10              Forks                   2
# 10                     11           Headsets                   2
# 11                     12    Mountain Frames                   2
# 12                     13             Pedals                   2
# ...

# %%
df_4
# Out:
#    ProductCategoryKey CategoryName
# 0                   1        Bikes
# 1                   2   Components
# 2                   3     Clothing
# 3                   4  Accessories

# %%
df_5
# Out:
#    SalesTerritoryKey          Region         Country      Continent
# 0                  1       Northwest   United States  North America
# 1                  2       Northeast   United States  North America
# 2                  3         Central   United States  North America
# 3                  4       Southwest   United States  North America
# 4                  5       Southeast   United States  North America
# 5                  6          Canada          Canada  North America
# 6                  7          France          France         Europe
# 7                  8         Germany         Germany         Europe
# 8                  9       Australia       Australia        Pacific
# 9                 10  United Kingdom  United Kingdom         Europe

# %%
Product = pd.merge(pd.merge(df_2,df_3,on='ProductSubcategoryKey'),df_4,on='ProductCategoryKey')

# %%
Product
# Out:
#      ProductKey  ProductSubcategoryKey  ProductSKU              ProductName  \
# 0           214                     31   HL-U509-R    Sport-100 Helmet, Red
# 1           215                     31     HL-U509  Sport-100 Helmet, Black
# 2           220                     31   HL-U509-B   Sport-100 Helmet, Blue
# 3           446                     35     PA-T100  Touring-Panniers, Large
# 4           447                     34     LO-C100               Cable Lock
# ..          ...                    ...         ...                      ...
# 288         577                      3  BK-T44U-46    Touring-2000 Blue, 46
# 289         578                      3  BK-T44U-50    Touring-2000 Blue, 50
# 290         579                      3  BK-T44U-54    Touring-2000 Blue, 54
# 291         585                      3  BK-T18U-44    Touring-3000 Blue, 44
# 292         586                      3  BK-T18U-50    Touring-3000 Blue, 50
#
# ...

# %%
ret_prod = pd.merge(Product,df_1,on='ProductKey')

# %%
df_5
# Out:
#    SalesTerritoryKey          Region         Country      Continent
# 0                  1       Northwest   United States  North America
# 1                  2       Northeast   United States  North America
# 2                  3         Central   United States  North America
# 3                  4       Southwest   United States  North America
# 4                  5       Southeast   United States  North America
# 5                  6          Canada          Canada  North America
# 6                  7          France          France         Europe
# 7                  8         Germany         Germany         Europe
# 8                  9       Australia       Australia        Pacific
# 9                 10  United Kingdom  United Kingdom         Europe

# %%
final_table = pd.merge(ret_prod,df_5,left_on='TerritoryKey',right_on='SalesTerritoryKey')

# %%
ret_prod
# Out:
#       ProductKey  ProductSubcategoryKey  ProductSKU            ProductName  \
# 0            214                     31   HL-U509-R  Sport-100 Helmet, Red
# 1            214                     31   HL-U509-R  Sport-100 Helmet, Red
# 2            214                     31   HL-U509-R  Sport-100 Helmet, Red
# 3            214                     31   HL-U509-R  Sport-100 Helmet, Red
# 4            214                     31   HL-U509-R  Sport-100 Helmet, Red
# ...          ...                    ...         ...                    ...
# 1804         578                      3  BK-T44U-50  Touring-2000 Blue, 50
# 1805         578                      3  BK-T44U-50  Touring-2000 Blue, 50
# 1806         579                      3  BK-T44U-54  Touring-2000 Blue, 54
# 1807         586                      3  BK-T18U-50  Touring-3000 Blue, 50
# 1808         586                      3  BK-T18U-50  Touring-3000 Blue, 50
#
# ...

# %%
final_table.to_csv('mydata.csv')
