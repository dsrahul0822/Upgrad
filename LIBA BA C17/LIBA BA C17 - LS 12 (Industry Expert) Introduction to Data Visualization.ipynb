# %% [markdown]
# # MatplotLib and Seaborn

# %% [markdown]
# **To understand the data we need to create Data Visualizations, so that we can interpret and take the actions**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# **https://matplotlib.org/**
#
# **https://seaborn.pydata.org/**

# %% [markdown]
# **Exploratory Data Analysis**
#
#     1) Univariate Analysis - When we are analysing only single variable, for example What's the age distribution i.e. Numerical feature, How many males and females are there? i.e. Categorical feature.
#
#     2) Bivariate Analysis - When we are analysing two variables, for example What's the relationship between Salary and Experience (Two numerical features), Average salary by Gender (One numerical and One categorical features)
#
#     3) Multivariate Analysis - When we are analysing three or more than three variables, for example Whats the relationship between Experience and Salary by Gender (Two numerical and one categorical features), What's the sales by Category and Segment (Two categoricals and one numerical)

# %%
dataset = pd.read_csv(r'E:\SmartCube\End to End Code\Python_Credit_Risk_XTrain.csv')

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Number of records in the dataframe**

# %%
len(dataset)
# Out:
# 614

# %% [markdown]
# **Number of columns in the dataframe**

# %%
len(dataset.columns)
# Out:
# 13

# %% [markdown]
# **Number of null values in the dataframe**

# %%
dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# **Structure of the dataframe**

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 62.5+ KB

# %% [markdown]
# **Gives the numerical features details in the dataframe**

# %%
dataset.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History  Loan_Status
# count      564.000000   614.000000
# mean         0.842199     0.687296
# std          0.364878     0.463973
# min          0.000000     0.000000
# 25%          1.000000     0.000000
# 50%          1.000000     1.000000
# 75%          1.000000     1.000000
# ...

# %%
dataset
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
import numpy as np
dataset.groupby('Gender').agg({'ApplicantIncome':np.mean})
# Out:
#         ApplicantIncome
# Gender
# Female      4643.473214
# Male        5446.460123

# %%
for group,data in dataset.groupby('Gender'):
    print(group,data['ApplicantIncome'].mean())
# Out:
# Female 4643.473214285715
# Male 5446.460122699386

# %% [markdown]
# # **Matplotlib**

# %% [markdown]
# **We cannot use Dataframe directly, we can use Series i.e. slice of a column, Lists, Tuples, Dictionaries or Sets**

# %%
plt.figure(figsize=(5,1))
for group,data in dataset.groupby('Gender'):
    plt.barh(group,data['ApplicantIncome'].mean())

# %%
dataset['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
property_dict = dict()
for i in set(dataset['Property_Area']):
    property_dict[i] = dataset[dataset['Property_Area']==i].Loan_ID.count()

# %%
plt.figure(figsize=(5,1))
plt.bar(property_dict.keys(), property_dict.values())
plt.xlabel('Property Type')
plt.ylabel('Count')
plt.title('Property Area vs Count')
plt.show()

# %%
plt.figure(figsize=(5,1))
plt.pie(property_dict.values(),labels=property_dict.keys())
plt.title('Property Area vs Count')
plt.show()

# %%
type(dataset['ApplicantIncome'])
# Out:
# pandas.core.series.Series

# %%
plt.figure(figsize=(5,1))
plt.scatter(dataset['ApplicantIncome'], dataset['CoapplicantIncome'])
plt.xlabel('Applicant Income')
plt.ylabel('Coapplicant Income')
plt.title('Application Vs Coapplicant')
plt.show()

# %%
plt.figure(figsize=(5,1))
plt.hist(dataset['ApplicantIncome'])
plt.show()

# %% [markdown]
# # Seaborn

# %%
sns.distplot(dataset['ApplicantIncome'],kde=False,color='Red')
# Out:
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ApplicantIncome'>

# %%
sns.countplot(data=dataset, x='Gender',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# **Gender does not matter to decide the loan status**

# %%
dataset
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.countplot(data=dataset, x='Married',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %% [markdown]
# **Married as a little chances to predict the loan status**

# %%
sns.countplot(data=dataset, x='Dependents',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %% [markdown]
# **Dependents does not matter to predict the loan status**

# %%
sns.countplot(data=dataset, x='Education',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# **If you are graduate there is a little higher chances that you will get a loan**

# %%
sns.countplot(data=dataset, x='Self_Employed',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Self_Employed', ylabel='count'>

# %% [markdown]
# **Self Employed is not really important variable to predict the loan status**

# %%
sns.countplot(data=dataset, x='Loan_Amount_Term',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Loan_Amount_Term', ylabel='count'>

# %% [markdown]
# **Majority of the customers are applying the loan for 360 months and those who are applying for 480 months there will be a higher changes to get rejection**

# %%
sns.countplot(data=dataset, x='Property_Area',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Property_Area', ylabel='count'>

# %% [markdown]
# **If customers are coming from the semiurban property the chances are higher to get a loan**

# %%
sns.countplot(data=dataset, x='Credit_History',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Credit_History', ylabel='count'>

# %% [markdown]
# **This feature i.e. Credit history is very important to predict the loan status**

# %%
sns.lmplot(data=dataset,x='ApplicantIncome',y='CoapplicantIncome',fit_reg=False,hue='Loan_Status')

# %%
sns.lmplot(data=dataset,x='ApplicantIncome',y='LoanAmount',fit_reg=False,hue='Loan_Status')

# %%
sns.lmplot(data=dataset,x='CoapplicantIncome',y='LoanAmount',fit_reg=False,hue='Loan_Status')

# %% [markdown]
# **The variables Coapplicant income, applicant income and loan amount is not really important to decide the loan status**

# %%
dataset_cars = pd.read_csv(r'E:\Courses\Python Basics to Advanced\Car_sales.csv')

# %%
plt.figure(figsize=(4,4))
sns.heatmap(dataset_cars[['Horsepower','Curb weight','Fuel efficiency','Fuel capacity']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(4,4))
sns.pairplot(dataset_cars[['Horsepower','Curb weight','Fuel efficiency','Fuel capacity','Vehicle type']],hue='Vehicle type')

# %%
sns.boxplot(data=dataset_cars, y='Vehicle type', x='Fuel capacity')
# Out:
# <AxesSubplot:xlabel='Fuel capacity', ylabel='Vehicle type'>

# %%
sns.violinplot(data=dataset_cars, y='Vehicle type', x='Fuel capacity')
# Out:
# <AxesSubplot:xlabel='Fuel capacity', ylabel='Vehicle type'>
